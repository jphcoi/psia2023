# %% [markdown]
# # **Text Classification using Language Model Fine-Tuning **
#
# Below is a brief tutorial to learn how to use BERT for sentence classification. It is largely inspired by a notebook written by Rubing Shen and makes use of a dedicated libray

# %% [markdown]
# *Since the resources on Google Colab are limited, you may bump into limitations when trying to use it for your own project. In this case, copy this notebook on your computational plateform to use it with your own GPU.*

# %% [markdown]
# ## Enabling GPU
#
# The package requires a GPU to run. To enable a GPU for this Notebook, you will need to:
# - Click 'Execution' in the menu bar, then click 'Modify '.
# - Select GPU from the Hardware Accelerator drop-down list, then click 'Save'.

# %% [markdown]
# Click on the arrow below to verify that you are successfully connected to a GPU. This should return the name of the GPU used.

# %%
from torch import cuda

cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# # Sentiment analysis off the shelf

# %%
pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 46.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 50.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.6 MB/s eta 0:00:00

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")#(many) alternative models exist - specific_model = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt: 0.00B [00:00, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
data = ["I love you", "I hate you"]
data=['anti trump  pro science  follow me and i follow back  blue wave 🌊', "i am an american nationalist and damn proud of it!!   trumptrain2020  maga  kag  gobucks no ❄❄❄", "a proud mom  grandma  and  aunt  doing what i can to prevent them from inheriting trump's america     america will unite for democracy  not a autocracy  resist"]
sentiment_pipeline(data)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.5591527223587036},
#  {'label': 'POSITIVE', 'score': 0.9988829493522644},
#  {'label': 'POSITIVE', 'score': 0.9998018145561218}]

# %% [markdown]
# ## Installing the package for fine-tuning

# %% [markdown]
# Run the cell below to install the package *AugmentedSocialScientist* on the current Google Colab runtime.

# %%
# !git clone https://github.com/rubingshen/AugmentedSocialScientist.git
# !pip install ./AugmentedSocialScientist/package/
# Out:
# Cloning into 'AugmentedSocialScientist'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 134 (delta 36), reused 50 (delta 13), pack-reused 35
# Receiving objects: 100% (134/134), 1.68 MiB | 17.54 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./AugmentedSocialScientist/package
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from AugmentedSocialScientist==0.1) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from AugmentedSocialScientist==0.1) (4.65.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from AugmentedSocialScientist==0.1) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from AugmentedSocialScientist==0.1) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from AugmentedSocialScientist==0.1) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from AugmentedSocialScientist==0.1) (3.8.1)
# Collecting keras==2.8 (from AugmentedSocialScientist==0.1)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.1 MB/s eta 0:00:00
# Collecting tensorflow==2.8 (from AugmentedSocialScientist==0.1)
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from AugmentedSocialScientist==0.1) (2.0.1+cu118)
# Collecting transformers (from AugmentedSocialScientist==0.1)
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 118.3 MB/s eta 0:00:00
# Collecting sentencepiece (from AugmentedSocialScientist==0.1)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (23.3.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (3.8.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8->AugmentedSocialScientist==0.1)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8->AugmentedSocialScientist==0.1)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 66.3 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8->AugmentedSocialScientist==0.1)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 49.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8->AugmentedSocialScientist==0.1) (1.54.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->AugmentedSocialScientist==0.1) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->AugmentedSocialScientist==0.1) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->AugmentedSocialScientist==0.1) (2022.10.31)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->AugmentedSocialScientist==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->AugmentedSocialScientist==0.1) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->AugmentedSocialScientist==0.1) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->AugmentedSocialScientist==0.1) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->AugmentedSocialScientist==0.1) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->AugmentedSocialScientist==0.1) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->AugmentedSocialScientist==0.1) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->AugmentedSocialScientist==0.1) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->AugmentedSocialScientist==0.1) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->AugmentedSocialScientist==0.1) (16.0.5)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->AugmentedSocialScientist==0.1)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 30.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->AugmentedSocialScientist==0.1) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->AugmentedSocialScientist==0.1) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->AugmentedSocialScientist==0.1) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->AugmentedSocialScientist==0.1)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 132.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->AugmentedSocialScientist==0.1)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 90.9 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8->AugmentedSocialScientist==0.1) (0.40.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->AugmentedSocialScientist==0.1) (2023.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (3.4.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 136.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (2.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->AugmentedSocialScientist==0.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->AugmentedSocialScientist==0.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->AugmentedSocialScientist==0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->AugmentedSocialScientist==0.1) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->AugmentedSocialScientist==0.1) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->AugmentedSocialScientist==0.1) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8->AugmentedSocialScientist==0.1) (3.2.2)
# Building wheels for collected packages: AugmentedSocialScientist
#   Building wheel for AugmentedSocialScientist (setup.py) ... done
#   Created wheel for AugmentedSocialScientist: filename=AugmentedSocialScientist-0.1-py3-none-any.whl size=13864 sha256=2f88af0bff6c927406ff612e3c33919d24d143315d358a098f1145806e6dbf08
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i4dgwcdb/wheels/f2/a3/ef/347e9750d4cbe887179294e9b5e53f0df3850d463bfd2e2f51
# Successfully built AugmentedSocialScientist
# Installing collected packages: tokenizers, tf-estimator-nightly, sentencepiece, safetensors, keras, tensorboard-data-server, keras-preprocessing, huggingface-hub, transformers, google-auth-oauthlib, tensorboard, tensorflow, AugmentedSocialScientist
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.2
#     Uninstalling tensorboard-2.12.2:
#       Successfully uninstalled tensorboard-2.12.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed AugmentedSocialScientist-0.1 google-auth-oauthlib-0.4.6 huggingface-hub-0.15.1 keras-2.8.0 keras-preprocessing-1.1.2 safetensors-0.3.1 sentencepiece-0.1.99 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109 tokenizers-0.13.3 transformers-4.30.2

# %% [markdown]
# Import other required packages for this tutorial.

# %%
import pandas as pd
import numpy as np

pd.options.display.max_colwidth=None
pd.options.display.max_rows=100

# %% [markdown]
# # **English Text Classifier Example: Clickbait Detection**

# %% [markdown]
# For this example, we use data from [Chakraborty et al. 2016](https://github.com/bhargaviparanjape/clickbait), in order to train a classifier that distinguishes between clickbait and non-clickbait titles

# %% [markdown]
# Import BERT model ([Devlin et al. 2019](https://arxiv.org/pdf/1810.04805.pdf)) from the package *AugmentedSocialScientist*.

# %%
from AugmentedSocialScientist import bert
# Out:
# There are 1 GPU(s) available.
# We will use GPU 0: Tesla T4
# Downloading (…)solve/main/vocab.txt: 0.00B [00:00, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %% [markdown]
# ### Loading data

# %%
cb_train = pd.read_csv('./AugmentedSocialScientist/datasets/english/clickbait_train.csv')
cb_test = pd.read_csv('./AugmentedSocialScientist/datasets/english/clickbait_test.csv')

# %% [markdown]
# Inspect loaded data

# %%
cb_train
# Out:
#                                                                       headline  \
# 0                11-Year-Old Bicyclist Called Out Reckless Drivers Like A Boss
# 1                            What Would Your Life Be Like As A Lame Super Hero
# 2    17 Faces Everyone Who's Experienced Halloween In The Cold Will Understand
# 3                                  16 Held in Coup Effort in Equatorial Guinea
# 4               Can You Guess The Celebrity Hiding Behind The Inanimate Object
# ..                                                                         ...
# 495   If You're Excited For The New "Star Wars" Movie You Have To See This Art
# 496                  Baseball Homecomings for Ken Griffey Jr. and Jason Giambi
# 497       13 Apps That'll Make Your iPhone-Android Relationship So Much Better
# 498                          What It Feels Like When You Make Your Crush Laugh
# 499                                    Should You Instagram Your Brunch Or Nah
#
#      is_clickbait
# 0               1
# 1               1
# 2               1
# 3               0
# 4               1
# ..            ...
# 495             1
# 496             0
# 497             1
# 498             1
# 499             1
#
# [500 rows x 2 columns]

# %%
cb_test
# Out:
#                                                                                                    headline  \
# 0                                                  North Queensland Fury sign former Liverpool great Fowler
# 1                                                                         US combat forces pull out of Iraq
# 2                                                                 Financial Unit Weighs on General Electric
# 3                                           Many Civilian Targets, but One Core Question Among Gazans: Why?
# 4                                                  18 Reasons You Should Avoid Lifting Weights At All Costs
# ..                                                                                                      ...
# 195  Band manager Daniel Biechele shown parole support by families of victims of the Station nightclub fire
# 196                                   Justin Trudeau Personally Welcomed A Plane Full Of Refugees To Canada
# 197                                                                  Which Sex Toy Matches Your Personality
# 198                                                         Who Is Your Celeb BFF Based On Your Birth Month
# 199                                                                                UK to ban Islamist group
#
#      is_clickbait
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1
# ..            ...
# 195             0
# 196             1
# 197             1
# 198             1
# 199             0
#
# [200 rows x 2 columns]

# %%
cb_test.xs(1)['is_clickbait']=[0,4]
# Out:
# <ipython-input-8-f72f6ea90da3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cb_test.xs(1)['is_clickbait']=[0,4]

# %% [markdown]
# ### Training a model

# %% [markdown]
# We will now encode the training and the test data.

# %%
train_loader = bert.encode(cb_train.headline.values, cb_train.is_clickbait.values)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
test_loader = bert.encode(cb_test.headline.values, cb_test.is_clickbait.values)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]

# %% [markdown]
# The following command trains, validates, and saves the model.
#
# To improve your accuracy, you can tune some hyperparameters
# *   n_epochs is the number of runs on all the training data;
# *   lr is the learning rate;
# *   seed_val is a random seed, for replicability purposes.
# *   save_model_as is the name of model saving folder. The model will be saved at `./models/<model_name>`. If you don't want to save the model after training, set this parameter to `None`.
#
# Once the model has completed its training phase, it calculates the F1-score (between 0 and 1) to assess the quality of the model.

# %%
score = bert.run_training(train_loader,
                          test_loader,
                          n_epochs=10,
                          lr=5e-6,
                          seed_val=42,
                          save_model_as='clickbait')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ======== Epoch 1 / 10 ========
# Training...
#
#   Average training loss: 0.67
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.62
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91       104
#            1       0.84      1.00      0.91        96
#
#     accuracy                           0.91       200
#    macro avg       0.92      0.91      0.91       200
# weighted avg       0.92      0.91      0.91       200
#
#
# ======== Epoch 2 / 10 ========
# Training...
#
#   Average training loss: 0.59
#   Training took: 0:00:02
#
# Running Validation...
#
#   Average test loss: 0.55
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       104
#            1       0.92      0.96      0.94        96
#
#     accuracy                           0.94       200
#    macro avg       0.94      0.94      0.94       200
# weighted avg       0.94      0.94      0.94       200
#
#
# ======== Epoch 3 / 10 ========
# Training...
#
#   Average training loss: 0.52
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.47
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       104
#            1       0.96      0.95      0.95        96
#
#     accuracy                           0.95       200
#    macro avg       0.96      0.95      0.95       200
# weighted avg       0.96      0.95      0.95       200
#
#
# ======== Epoch 4 / 10 ========
# Training...
#
#   Average training loss: 0.45
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.40
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       104
#            1       0.96      0.96      0.96        96
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200
#
#
# ======== Epoch 5 / 10 ========
# Training...
#
#   Average training loss: 0.37
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.34
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       104
#            1       0.92      0.98      0.95        96
#
#     accuracy                           0.95       200
#    macro avg       0.95      0.95      0.95       200
# weighted avg       0.95      0.95      0.95       200
#
#
# ======== Epoch 6 / 10 ========
# Training...
#
#   Average training loss: 0.31
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.30
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       104
#            1       0.92      0.98      0.95        96
#
#     accuracy                           0.95       200
#    macro avg       0.95      0.95      0.95       200
# weighted avg       0.95      0.95      0.95       200
#
#
# ======== Epoch 7 / 10 ========
# Training...
#
#   Average training loss: 0.27
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.27
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       104
#            1       0.94      0.98      0.96        96
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200
#
#
# ======== Epoch 8 / 10 ========
# Training...
#
#   Average training loss: 0.23
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.26
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97       104
#            1       0.94      0.99      0.96        96
#
#     accuracy                           0.96       200
#    macro avg       0.97      0.97      0.96       200
# weighted avg       0.97      0.96      0.97       200
#
#
# ======== Epoch 9 / 10 ========
# Training...
#
#   Average training loss: 0.21
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.25
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       104
#            1       0.93      0.99      0.96        96
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200
#
#
# ======== Epoch 10 / 10 ========
# Training...
#
#   Average training loss: 0.20
#   Training took: 0:00:03
#
# Running Validation...
#
#   Average test loss: 0.25
#   Validation took: 0:00:00
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       104
#            1       0.93      0.99      0.96        96
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200
#
#
# Training complete!

# %% [markdown]
# ### Predicting on new data

# %% [markdown]
# Load unlabelled data for prediction, inspect it.

# %%
cb_pred = pd.read_csv('./AugmentedSocialScientist/datasets/english/clickbait_pred.csv')

# %%
cb_pred
# Out:
#                                                                                headline
# 0                              34 Musical Baby Names That'll Make You Want To Procreate
# 1                                      Senate Approves Tight Regulation Over Cigarettes
# 2   Scotland predicted to have worst recession since 1980, but not as bad as rest of UK
# 3                                17 Times Chloe The Mini Frenchie Won Instagram In 2015
# 4                                    Markets rally as world's central banks infuse cash
# 5                        17 Photos Everyone Who Grew Up Eating Pan Dulce Will Relate To
# 6                    Zimbabwean opposition leader rejects calls for power sharing talks
# 7                                                          Chief of Swiss Re Steps Down
# 8      This Guy's Epic Story Explains Why Every Girl Has A Trapped In The Closet Moment
# 9        There's A New Trailer For The "Sherlock" Christmas Special And It's Pure Magic
# 10                                     Six dead in arson attack in Bridgetown, Barbados
# 11                                22 Super Annoying Things Every Woman Has To Deal With
# 12               English Cricket Teams Get Uneven Treatment Everywhere but on the Field
# 13                                        Mayor Aims to Add Spark to Flagging Sex Lives
# 14                               22 Hilarious Tweets About Being Exhausted All The Time
# 15    Nations begin to offer aid to regions afflicted by Indian subcontinent earthquake
# 16                                         U.S. Captain Hears Pleas for Afghan Detainee
# 17                    Daw Aung San Suu Kyi, Burmese Pro-Democracy Leader, Goes on Trial
# 18                                       Stronger Euro Threatens Weak Economy in Europe
# 19                                               UK's BAA forced to sell three airports
# 20                                We Know Who You Plan On Spending Valentine's Day With
# 21                  Suicide bomber attacks Indian Embassy in Kabul, killing at least 41
# 22                                          31 Gifts For People Who Freakin' Love Fruit
# 23                                     21 Times Chris Pratt Was Too Good For This World
# 24                                   24 Times Kris Jenner Was Shut Down By Her Own Kids
# 25                  French teacher returns home after being held in Iran for ten months
# 26                                30 Face Swaps That Will Make You Really Uncomfortable
# 27                   10 Mundane Things About Fall That Are Actually The Most Terrifying
# 28                                22 Genius Running Hacks For When It's Cold AF Outside
# 29                         21 Truths For People Who Like Animals More Than Other Humans
# 30                    UK study reveals smoking could shorten men's lives by 10–15 years
# 31                          Rumours suggest Alonso and Schumacher could move to Ferrari
# 32                                                  18 Cake GIFs That'll Make You Moist
# 33         We Know Your Favorite Male Celebrity Based On Your Favorite Female Celebrity
# 34                                                Nonprofits Seek Lobby Rule Exceptions
# 35              13 Celebs Who Totally Got Dressed Up For "Star Wars: The Force Awakens"
# 36                                         16 Things Dudes Need To Stop Wearing In 2016
# 37                                                 Deere Profit Fell 38% in 2nd Quarter
# 38                                             Major League Soccer 2008: Week 7 roundup
# 39                             22 Insanely Adorable DIY Decorations For Holiday Parties
# 40                                 Delicacy of the Wild West Lives on for Those So Bold
# 41                          17 Reasons Why Jos. Louis Are The Ultimate Culinary Delight
# 42                                                18 Hilarious Tweets About Going Vegan
# 43                                      27 Kids Who Totally Nailed This Halloween Thing
# 44                        Mathematics summer school in Turkey threatened by authorities
# 45                         These Star Wars Carbonite "Pop-Tarts" Are Too Cool For Words
# 46                                              What "No Name" Product Are You Actually
# 47              Search continues for nine missing after midair collision off California
# 48                              25 Things You'll Only Get If You're Obsessed With Baths
# 49            American TV personality and "Tonight Show" sidekick Ed McMahon dies at 86

# %% [markdown]
# Encode your prediction data

# %%
pred_loader = bert.encode(cb_pred.headline.values)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# Predict using the saved model

# %%
pred_proba = bert.predict_with_model(pred_loader, model_path='./models/clickbait')
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Output: the model returns the probabiliby of each headline in the unlabelled data set to belong to a given category (0: not clickbait; 1: clickbait).

# %%
pred_proba
# Out:
# array([[0.08891816, 0.9110818 ],
#        [0.8865426 , 0.11345742],
#        [0.88926005, 0.11073996],
#        [0.19879048, 0.80120957],
#        [0.8728297 , 0.1271703 ],
#        [0.16549903, 0.83450097],
#        [0.89192766, 0.10807239],
#        [0.88374555, 0.11625442],
#        [0.16703835, 0.8329616 ],
#        [0.16628607, 0.83371395],
#        [0.8917807 , 0.10821937],
#        [0.09156585, 0.90843415],
#        [0.8149036 , 0.18509638],
#        [0.8534682 , 0.14653182],
#        [0.15306884, 0.8469311 ],
#        [0.88547766, 0.1145223 ],
#        [0.89769644, 0.10230357],
#        [0.8708133 , 0.12918669],
#        [0.8773369 , 0.12266309],
#        [0.90423006, 0.09576995],
#        [0.16928744, 0.8307126 ],
#        [0.8832665 , 0.11673348],
#        [0.11754417, 0.8824559 ],
#        [0.11646442, 0.88353556],
#        [0.13959594, 0.860404  ],
#        [0.871242  , 0.12875801],
#        [0.11747322, 0.8825268 ],
#        [0.12624456, 0.87375546],
#        [0.12507081, 0.87492925],
#        [0.15531169, 0.8446883 ],
#        [0.8103202 , 0.18967983],
#        [0.8735308 , 0.12646918],
#        [0.1333269 , 0.8666731 ],
#        [0.16988474, 0.8301152 ],
#        [0.86508644, 0.13491364],
#        [0.15334463, 0.84665537],
#        [0.09659339, 0.90340656],
#        [0.86572474, 0.13427524],
#        [0.8513113 , 0.14868872],
#        [0.09725764, 0.9027424 ],
#        [0.24450526, 0.7554948 ],
#        [0.1261114 , 0.8738886 ],
#        [0.12108798, 0.87891203],
#        [0.11231816, 0.8876819 ],
#        [0.88795346, 0.1120466 ],
#        [0.14360526, 0.8563947 ],
#        [0.16498451, 0.8350155 ],
#        [0.8773634 , 0.12263669],
#        [0.08269758, 0.9173024 ],
#        [0.8429169 , 0.15708306]], dtype=float32)

# %% [markdown]
# Store the predicted category and probability to the dataframe

# %%
cb_pred['pred_label'] = np.argmax(pred_proba, axis=1)
cb_pred['pred_proba'] = np.max(pred_proba, axis=1)

# %% [markdown]
# Inspect the prediction results

# %%
for i in range(len(cb_pred)):
    print(f"{cb_pred.loc[i,'headline']}")
    print(f"Is clickbait: {bool(cb_pred.loc[i,'pred_label'])}, with a probability of {cb_pred.loc[i,'pred_proba']*100:.0f}%")
    print()
# Out:
# 34 Musical Baby Names That'll Make You Want To Procreate
# Is clickbait: True, with a probability of 91%
#
# Senate Approves Tight Regulation Over Cigarettes
# Is clickbait: False, with a probability of 89%
#
# Scotland predicted to have worst recession since 1980, but not as bad as rest of UK
# Is clickbait: False, with a probability of 89%
#
# 17 Times Chloe The Mini Frenchie Won Instagram In 2015
# Is clickbait: True, with a probability of 80%
#
# Markets rally as world's central banks infuse cash
# Is clickbait: False, with a probability of 87%
#
# 17 Photos Everyone Who Grew Up Eating Pan Dulce Will Relate To
# Is clickbait: True, with a probability of 83%
#
# Zimbabwean opposition leader rejects calls for power sharing talks
# Is clickbait: False, with a probability of 89%
#
# Chief of Swiss Re Steps Down
# Is clickbait: False, with a probability of 88%
#
# This Guy's Epic Story Explains Why Every Girl Has A Trapped In The Closet Moment
# Is clickbait: True, with a probability of 83%
#
# There's A New Trailer For The "Sherlock" Christmas Special And It's Pure Magic
# Is clickbait: True, with a probability of 83%
#
# Six dead in arson attack in Bridgetown, Barbados
# Is clickbait: False, with a probability of 89%
#
# 22 Super Annoying Things Every Woman Has To Deal With
# Is clickbait: True, with a probability of 91%
#
# English Cricket Teams Get Uneven Treatment Everywhere but on the Field
# Is clickbait: False, with a probability of 81%
#
# Mayor Aims to Add Spark to Flagging Sex Lives
# Is clickbait: False, with a probability of 85%
#
# 22 Hilarious Tweets About Being Exhausted All The Time
# Is clickbait: True, with a probability of 85%
#
# Nations begin to offer aid to regions afflicted by Indian subcontinent earthquake
# Is clickbait: False, with a probability of 89%
#
# U.S. Captain Hears Pleas for Afghan Detainee
# Is clickbait: False, with a probability of 90%
#
# Daw Aung San Suu Kyi, Burmese Pro-Democracy Leader, Goes on Trial
# Is clickbait: False, with a probability of 87%
#
# Stronger Euro Threatens Weak Economy in Europe
# Is clickbait: False, with a probability of 88%
#
# UK's BAA forced to sell three airports
# Is clickbait: False, with a probability of 90%
#
# We Know Who You Plan On Spending Valentine's Day With
# Is clickbait: True, with a probability of 83%
#
# Suicide bomber attacks Indian Embassy in Kabul, killing at least 41
# Is clickbait: False, with a probability of 88%
#
# 31 Gifts For People Who Freakin' Love Fruit
# Is clickbait: True, with a probability of 88%
#
# 21 Times Chris Pratt Was Too Good For This World
# Is clickbait: True, with a probability of 88%
#
# 24 Times Kris Jenner Was Shut Down By Her Own Kids
# Is clickbait: True, with a probability of 86%
#
# French teacher returns home after being held in Iran for ten months
# Is clickbait: False, with a probability of 87%
#
# 30 Face Swaps That Will Make You Really Uncomfortable
# Is clickbait: True, with a probability of 88%
#
# 10 Mundane Things About Fall That Are Actually The Most Terrifying
# Is clickbait: True, with a probability of 87%
#
# 22 Genius Running Hacks For When It's Cold AF Outside
# Is clickbait: True, with a probability of 87%
#
# 21 Truths For People Who Like Animals More Than Other Humans
# Is clickbait: True, with a probability of 84%
#
# UK study reveals smoking could shorten men's lives by 10–15 years
# Is clickbait: False, with a probability of 81%
#
# Rumours suggest Alonso and Schumacher could move to Ferrari
# Is clickbait: False, with a probability of 87%
#
# 18 Cake GIFs That'll Make You Moist
# Is clickbait: True, with a probability of 87%
#
# We Know Your Favorite Male Celebrity Based On Your Favorite Female Celebrity
# Is clickbait: True, with a probability of 83%
#
# Nonprofits Seek Lobby Rule Exceptions
# Is clickbait: False, with a probability of 87%
#
# 13 Celebs Who Totally Got Dressed Up For "Star Wars: The Force Awakens"
# Is clickbait: True, with a probability of 85%
#
# 16 Things Dudes Need To Stop Wearing In 2016
# Is clickbait: True, with a probability of 90%
#
# Deere Profit Fell 38% in 2nd Quarter
# Is clickbait: False, with a probability of 87%
#
# Major League Soccer 2008: Week 7 roundup
# Is clickbait: False, with a probability of 85%
#
# 22 Insanely Adorable DIY Decorations For Holiday Parties
# Is clickbait: True, with a probability of 90%
#
# Delicacy of the Wild West Lives on for Those So Bold
# Is clickbait: True, with a probability of 76%
#
# 17 Reasons Why Jos. Louis Are The Ultimate Culinary Delight
# Is clickbait: True, with a probability of 87%
#
# 18 Hilarious Tweets About Going Vegan
# Is clickbait: True, with a probability of 88%
#
# 27 Kids Who Totally Nailed This Halloween Thing
# Is clickbait: True, with a probability of 89%
#
# Mathematics summer school in Turkey threatened by authorities
# Is clickbait: False, with a probability of 89%
#
# These Star Wars Carbonite "Pop-Tarts" Are Too Cool For Words
# Is clickbait: True, with a probability of 86%
#
# What "No Name" Product Are You Actually
# Is clickbait: True, with a probability of 84%
#
# Search continues for nine missing after midair collision off California
# Is clickbait: False, with a probability of 88%
#
# 25 Things You'll Only Get If You're Obsessed With Baths
# Is clickbait: True, with a probability of 92%
#
# American TV personality and "Tonight Show" sidekick Ed McMahon dies at 86
# Is clickbait: False, with a probability of 84%

# %% [markdown]
# # For Other Languages

# %% [markdown]
# For other languages, the pacakge contains a multilingual model: XLM-RoBERTa  ([Goyal et al. 2020](https://arxiv.org/abs/1911.02116)), which is able to perform NLP tasks on 100 different languages (see Appendix A in the paper for a list).

# %% [markdown]
# To use it, the syntax is the same as with BERT and CamemBERT. You first need to import the model `xlmroberta` from the package.

# %%
from AugmentedSocialScientist import xlmroberta
# Out:
# There are 1 GPU(s) available.
# We will use GPU 0: Tesla T4
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]

# %% [markdown]
# Once imported, you can then use the functions `xlmroberta.encode`, `xlmroberta.run_training`, `xlmroberta.predict_with_model` with the same syntax as for BERT and CamemBERT.

# %% [markdown]
# However, this multilingual model requires a significant amount of RAM which may exceed the capacity of Google Colab. In this case, try to run the model on your own GPU server.
